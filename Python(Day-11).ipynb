# %%
# from collections import UserList
# import pandas as pd
# import pandas as pd
# # ld -> method series
# l = [10,20,30]
# df = pd.Series(l)
# print(df)

#example 2
# d = {"name":"yash","age":"20","roll-no":35}
# df = pd.Series(d,index=["name","age","roll-no"])
# print(df)

# import pandas as pd
# d = {"name":["kunal","dheeraj","yash","praveen","raj"],"roll-no":[12,13,14,15,16]}
# df = pd.DataFrame(data=d)
# print(df)

#csv file import from github
import pandas as pd
url = "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2%20-%20Sheet1.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
