# %%
# csv file import from github
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)

# head -> starting 5 rows
print(df.head())

# head->2 rows data
print(df.head(2))

# head ->negative number
print(df.head(-2))

#tail -> used to get last 5 rows data
df.tail(2)
df.tail(-4)

import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df = pd.read_json(url)
df.info()
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#       name  roll no  marks
# 0  dheeraj      123     10
# 1    kunal     1234     20
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   roll no  5 non-null      int64
#  2   marks    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df = pd.read_json(url)
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   roll no  5 non-null      int64
#  2   marks    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
print(df.shape)
# Out:
# (5, 3)

# %%
import pandas as pd
#url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df = pd.DataFrame(data=[10,20,30,40,50])
print(df)
df.shape
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# (5, 1)

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df = pd.read_json(url)
df.rename(columns={"name":"student_name","marks":"salary"},inplace=True)
print(df)
# Out:
#   student_name  roll no  salary
# 0      dheeraj      123      10
# 1        kunal     1234      20
# 2     abhishek    12345      30
# 3      praveen    12356      40
# 4       anjali  1234567      50

# %%
import pandas as pd

data = {
    "Emp_ID": [101, 102, 103, 104, 105, 106],
    "Name": ["Amit", "Riya", "Raj", "Sara", "John", "Neha"],
    "Department": ["IT", "HR", "Finance", "IT", "Sales", "HR"],
    "Salary": [50000, 45000, 60000, 55000, 48000, 52000],
    "Experience": [2, 3, 5, 4, 1, 3]
}

df = pd.DataFrame(data)
print(df.head(2))
print("..................")
print(df.shape)
print("..................")
print(df.info)
print("..................")
print(df.describe)
print("..................")
print(df.rename(columns={"Department":"Sector"}))
print("..................")
# Out:
#    Emp_ID  Name Department  Salary  Experience
# 0     101  Amit         IT   50000           2
# 1     102  Riya         HR   45000           3
# ..................
# (6, 5)
# ..................
# <bound method DataFrame.info of    Emp_ID  Name Department  Salary  Experience
# 0     101  Amit         IT   50000           2
# 1     102  Riya         HR   45000           3
# 2     103   Raj    Finance   60000           5
# 3     104  Sara         IT   55000           4
# 4     105  John      Sales   48000           1
# 5     106  Neha         HR   52000           3>
# ..................
# <bound method NDFrame.describe of    Emp_ID  Name Department  Salary  Experience
# 0     101  Amit         IT   50000           2
# 1     102  Riya         HR   45000           3
# 2     103   Raj    Finance   60000           5
# 3     104  Sara         IT   55000           4
# 4     105  John      Sales   48000           1
# 5     106  Neha         HR   52000           3>
# ..................
# ...

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df = pd.read_json(url)
print(df)
# get single column data
df["name"]
# # add single column
df["salary"] = df["marks"]* 100
print(df)
# #add single  coulmn
df["salary"] = [100,200,300,400,500]
df
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#        name  roll no  marks  salary
# 0   dheeraj      123     10    1000
# 1     kunal     1234     20    2000
# 2  abhishek    12345     30    3000
# 3   praveen    12356     40    4000
# 4    anjali  1234567     50    5000
#        name  roll no  marks  salary
# 0   dheeraj      123     10     100
# 1     kunal     1234     20     200
# 2  abhishek    12345     30     300
# 3   praveen    12356     40     400
# 4    anjali  1234567     50     500

# %%
import pandas as pd
d = {
    "name":["vishal","vineet","virat"],      #3rows
    "salary":[100,200,300]                  #3rows
}
df=pd.DataFrame(data=d)
#add column
# df["marks"] = [10,20,30]
df["marks"]=df["salary"] /2
print(df)
df["increment"] = df["salary"]  + (df["salary"] / 10)
# column name change
df.rename(columns={"increment":"salary_increment"},inplace=True)
print(df)
# Out:
#      name  salary  marks
# 0  vishal     100   50.0
# 1  vineet     200  100.0
# 2   virat     300  150.0
#      name  salary  marks  salary_increment
# 0  vishal     100   50.0             110.0
# 1  vineet     200  100.0             220.0
# 2   virat     300  150.0             330.0
