# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
df.isnull()
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#     name  roll no  marks
# 0  False    False  False
# 1  False    False  False
# 2  False    False  False
# 3  False    False  False
# 4  False    False  False

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
#-> anjali's only marks should be null
df.loc[4]
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
# name        anjali
# roll no    1234567
# marks           50
# Name: 4, dtype: object

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
#-> anjali marks should be done
df.loc[4,"marks"] = "null"
df.loc[4]
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
# /tmp/ipykernel_1450/853810119.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'null' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[4,"marks"] = "null"
# name        anjali
# roll no    1234567
# marks         null
# Name: 4, dtype: object

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
#-> anjali marks should be done
df.loc[4,"marks"] = None
df.isnull()
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#     name  roll no  marks
# 0  False    False  False
# 1  False    False  False
# 2  False    False  False
# 3  False    False  False
# 4  False    False   True

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
#-> anjali marks should be done
df.loc[4,"marks"] = None
df.loc[4]
#-> for column count missing values
df.isnull().sum()
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
# name       0
# roll no    0
# marks      1
# dtype: int64

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123    NaN
# 1     kunal     1234   20.0
# 2  abhishek    12345   30.0
# 3   praveen    12356   40.0
# 4    anjali  1234567   50.0

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
# to remove nulll values
df.dropna()
# Out:
#        name  roll no  marks
# 0   dheeraj      123    NaN
# 1     kunal     1234   20.0
# 2  abhishek    12345   30.0
# 3   praveen    12356   40.0
# 4    anjali  1234567   50.0
#        name  roll no  marks
# 1     kunal     1234   20.0
# 2  abhishek    12345   30.0
# 3   praveen    12356   40.0
# 4    anjali  1234567   50.0

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
# to remove of column with null values
print(df.dropna(axis=1))
# Out:
#        name  roll no  marks
# 0   dheeraj      123    NaN
# 1     kunal     1234   20.0
# 2  abhishek    12345   30.0
# 3   praveen    12356   40.0
# 4    anjali  1234567   50.0
#        name  roll no
# 0   dheeraj      123
# 1     kunal     1234
# 2  abhishek    12345
# 3   praveen    12356
# 4    anjali  1234567

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
# to replace nan with a values
df.fillna(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1450/3951508762.py in <cell line: 0>()
#       1 import pandas as pd
#       2 url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
# ----> 3 df=pd.read_json(url)
#       4 print(df)
#       5 # to replace nan with a values
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
#     816
#     817
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read(self)
#    1023                         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024                 else:
# -> 1025                     obj = self._get_object_parser(self.data)
#    1026                 if self.dtype_backend is not lib.no_default:
#    1027                     return obj.convert_dtypes(
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#    1049         obj = None
#    1050         if typ == "frame":
# -> 1051             obj = FrameParser(json, **kwargs).parse()
#    1052
#    1053         if typ == "series" or obj is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in parse(self)
#    1185     @final
#    1186     def parse(self):
# -> 1187         self._parse()
#    1188
#    1189         if self.obj is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in _parse(self)
#    1401         if orient == "columns":
#    1402             self.obj = DataFrame(
# -> 1403                 ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404             )
#    1405         elif orient == "split":
#
# ValueError: Unexpected character found when decoding object value

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
df=pd.read_json(url)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1450/2367856099.py in <cell line: 0>()
#       1 import pandas as pd
#       2 url =  "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/file2.json"
# ----> 3 df=pd.read_json(url)
#       4 print(df)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
#     816
#     817
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read(self)
#    1023                         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024                 else:
# -> 1025                     obj = self._get_object_parser(self.data)
#    1026                 if self.dtype_backend is not lib.no_default:
#    1027                     return obj.convert_dtypes(
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#    1049         obj = None
#    1050         if typ == "frame":
# -> 1051             obj = FrameParser(json, **kwargs).parse()
#    1052
#    1053         if typ == "series" or obj is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in parse(self)
#    1185     @final
#    1186     def parse(self):
# -> 1187         self._parse()
#    1188
#    1189         if self.obj is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in _parse(self)
#    1401         if orient == "columns":
#    1402             self.obj = DataFrame(
# -> 1403                 ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404             )
#    1405         elif orient == "split":
#
# ValueError: Unexpected character found when decoding object value
