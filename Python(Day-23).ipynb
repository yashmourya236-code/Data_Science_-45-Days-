# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler , LabelEncoder
url = "https://raw.githubusercontent.com/yashmourya236-code/Data_Science_-45-Days-/main/moviesTMBD.csv"
df = pd.read_csv(url)
print(df)
print('\n')

#to clean the data
df.drop(["id" , "title" , "adult" , "original_language" , "overview" , "release_date" , "Unnamed: 0"], axis = 1 ,inplace = True)
print(df)



#feature scaling
scaler = StandardScaler()
df[["vote_average","vote_count"]] = scaler.fit_transform(df[["vote_average","vote_count"]])
print(df)


#split data
x = df[["vote_average" ,"vote_count"]]
y = df[["popularity"]]


#train_test_split
x_train ,x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)

print(x_train)
print('\n')

print(x_test)
print('\n')

print(y_train)
print('\n')

print(y_test)
print('\n')

#model training
model = LinearRegression()
model.fit(x_train , y_train)

#pridiction
n_vote = int(input("Enter No. Of Votes : "))
avg_vote = float(input("Enter No. Of Avg Votes : "))

New_data =pd.DataFrame(
     {
    "vote_average" : [avg_vote],
    "vote_count" : [n_vote]
}
)
# New_df = pd.DataFrame(New_data)
New_data[["vote_average","vote_count"]] = scaler.fit_transform(New_data[["vote_average","vote_count"]])

predicted_pop = model.predict(New_data)
print("The Popularity Will Be -> " ,predicted_pop[0])
# Out:
#       Unnamed: 0       id                     title  popularity  adult  \
# 0              0  1007757                   Swapped    327.5134  False
# 1              1      278  The Shawshank Redemption     65.3308  False
# 2              2      238             The Godfather     47.2346  False
# 3              3   687163         Project Hail Mary    422.0199  False
# 4              4      240     The Godfather Part II     27.6763  False
# ...          ...      ...                       ...         ...    ...
# 9975        9975   399173            The Assignment      2.1132  False
# 9976        9976   613377               30 Days Max      1.2237  False
# 9977        9977     8859     Dude, Where's My Car?      2.8157  False
# 9978        9978   313943                    Revolt      1.4022  False
# 9979        9979   277355                    Everly      2.0746  False
#
#      original_language                                           overview  \
# 0                   en  A small woodland creature and a majestic bird,...
# 1                   en  Imprisoned in the 1940s for the double murder ...
# 2                   en  Spanning the years 1945 to 1955, a chronicle o...
# 3                   en  Science teacher Ryland Grace wakes up on a spa...
# 4                   en  In the continuing saga of the Corleone crime f...
# ...                ...                                                ...
# 9975                en  Ace assassin Frank Kitchen is double crossed b...
# 9976                fr  Rayane is a scared and clumsy young cop who is...
# 9977                en  Two stoners wake up after a night of partying ...
# 9978                en  The story of humankind's last stand against a ...
# 9979                en  After she betrays a powerful mob boss, a woman...
#
#      release_date  vote_average  vote_count
# 0      2026-05-01         8.987        1320
# 1      1994-09-23         8.721       30387
# 2      1972-03-14         8.686       22929
# 3      2026-03-15         8.621        3950
# 4      1974-12-20         8.571       13901
# ...           ...           ...         ...
# 9975   2016-06-08         5.538         560
# 9976   2020-10-14         5.500         407
# 9977   2000-12-15         5.538        2080
# 9978   2017-07-01         5.537         393
# 9979   2015-02-26         5.536         584
#
# [9980 rows x 10 columns]
#
#
#       popularity  vote_average  vote_count
# 0       327.5134         8.987        1320
# 1        65.3308         8.721       30387
# 2        47.2346         8.686       22929
# 3       422.0199         8.621        3950
# 4        27.6763         8.571       13901
# ...          ...           ...         ...
# 9975      2.1132         5.538         560
# 9976      1.2237         5.500         407
# 9977      2.8157         5.538        2080
# 9978      1.4022         5.537         393
# 9979      2.0746         5.536         584
#
# [9980 rows x 3 columns]
#       popularity  vote_average  vote_count
# 0       327.5134      3.489420   -0.235775
# 1        65.3308      3.074444    8.380578
# 2        47.2346      3.019842    6.169797
# 3       422.0199      2.918439    0.543837
# 4        27.6763      2.840436    3.493620
# ...          ...           ...         ...
# 9975      2.1132     -1.891221   -0.461063
# 9976      1.2237     -1.950503   -0.506417
# 9977      2.8157     -1.891221   -0.010488
# 9978      1.4022     -1.892781   -0.510567
# 9979      2.0746     -1.894341   -0.453949
#
# [9980 rows x 3 columns]
#       vote_average  vote_count
# 2943      0.581471    1.868883
# 7791     -0.858462    1.074152
# 1298      1.182094    1.410008
# 2588      0.709396   -0.038945
# 3527      0.394264   -0.256526
# ...            ...         ...
# 5734     -0.256280   -0.411559
# 5191     -0.100274   -0.392291
# 5390     -0.156436   -0.260676
# 860       1.481625   -0.259786
# 7270     -0.718057   -0.532503
#
# [7984 rows x 2 columns]
#
#
#       vote_average  vote_count
# 1253      1.196134   -0.316998
# 8224     -1.025389   -0.464620
# 1658      1.037008    1.470184
# 7733     -0.870943   -0.526574
# 1441      1.121251    0.081405
# ...            ...         ...
# 9496     -1.482486   -0.534874
# 210       2.072887   -0.128171
# 7826     -0.899024    1.694878
# 1919      0.926244   -0.140918
# 718       1.537787   -0.275794
#
# [1996 rows x 2 columns]
#
#
#       popularity
# 2943     10.2404
# 7791      4.0185
# 1298     11.8619
# 2588      6.4622
# 3527      1.7207
# ...          ...
# 5734      1.8307
# 5191      1.5952
# 5390      3.4943
# 860       3.4127
# 7270      2.0236
#
# [7984 rows x 1 columns]
#
#
#       popularity
# 1253      2.2430
# 8224      1.7793
# 1658      9.5486
# 7733      1.8090
# 1441      6.3742
# ...          ...
# 9496      2.1480
# 210       4.1647
# 7826      0.3995
# 1919     10.4101
# 718       0.7576
#
# [1996 rows x 1 columns]
